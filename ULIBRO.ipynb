# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelOrtega630/IA_2025/blob/main/ULIBRO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Quest ulibro

# %% [markdown]
# ##Fotos del evento

# %% [markdown]
# ![1000042702.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![1000042402.jpg](data:image/jpeg;base64,...)
